# %%
import os
#get files in directory
files = os.listdir("./sample_data")
print(files)
#Jupyter hotkeys:
#https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/
# Out:
# ['supermarkets-commas.txt', 'supermarkets-semi-colons.txt', 'supermarkets.csv', 'supermarkets.json', 'supermarkets.xlsx']

# %%
import pandas
#read standard csv, delimited by commas
df1 = pandas.read_csv("./sample_data/supermarkets.csv")
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#get the data frame's shape
df1.shape
# Out:
# (6, 7)

# %%
#read a json formatted object
df2 = pandas.read_json("./sample_data/supermarkets.json")
df2.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
#read an excel file at sheet index of 0
df3 = pandas.read_excel("./sample_data/supermarkets.xlsx", sheetname=0)
df3.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
#read a text file separated by commas
df4 = pandas.read_csv("./sample_data/supermarkets-commas.txt")
df4.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#read a text file separated by semi colons
df5 = pandas.read_csv("./sample_data/supermarkets-semi-colons.txt", sep=";")
df5.set_index("ID")
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#for help (jupyter specifc)
#pandas.read_csv?
# Out:
#   File "<ipython-input-12-27bc9ec73cf7>", line 1
#     pandas.read_csv?
#                    ^
# SyntaxError: invalid syntax

# %%
#read csv from a website
df6 = pandas.read_csv("http://pythonhow.com/supermarkets.csv")
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#read json file from a website
df7 = pandas.read_json("http://pythonhow.com/supermarkets.json")
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
#splicing dataframes
df8 = pandas.read_csv("./sample_data/supermarkets-semi-colons.txt", sep=";")
df8 = df8.set_index("Address")
df8
# Out:
#                  ID           City             State Country          Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA       Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA   Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA       Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
#label indexing 
#["start row" (:)to "end row" (,)by "start column" to "end column"]
df8.loc["735 Dolores St" : "332 Hill St", "ID" : "State"]
# Out:
#                 ID           City             State
# Address
# 735 Dolores St   2  San Francisco          CA 94119
# 332 Hill St      3  San Francisco  California 94114

# %%
#convert to a list
lst = list(df8.loc[:, "Country"])
lst
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df8
# Out:
#                  ID           City             State Country          Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA       Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA   Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA       Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
#by index
df8.iloc[1:3, 1:3]
# Out:
#                          City             State
# Address
# 735 Dolores St  San Francisco          CA 94119
# 332 Hill St     San Francisco  California 94114

# %%
#enter a combination of rows and indexes
#df8.ix["Name", 4] #deprecated
df8
# Out:
#                  ID           City             State Country          Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA       Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA   Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA       Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df8.drop("City", 1) #about to delete column indicated by passing 1, 0 to delete a row
# Out:
#                  ID             State Country          Name  Employees
# Address
# 3666 21st St      1          CA 94114     USA       Madeira          8
# 735 Dolores St    2          CA 94119     USA   Bready Shop         15
# 332 Hill St       3  California 94114     USA   Super River         25
# 3995 23rd St      4          CA 94114     USA    Ben's Shop         10
# 1056 Sanchez St   5        California     USA       Sanchez         12
# 551 Alvarado St   6          CA 94114     USA    Richvalley         20

# %%
df8.drop(df8.index[0:3], 0)
# Out:
#                  ID           City       State Country        Name  Employees
# Address
# 3995 23rd St      4  San Francisco    CA 94114     USA  Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA     Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA  Richvalley         20

# %%
df8.drop(df8.columns[0:3], 1)
# Out:
#                 Country          Name  Employees
# Address
# 3666 21st St        USA       Madeira          8
# 735 Dolores St      USA   Bready Shop         15
# 332 Hill St         USA   Super River         25
# 3995 23rd St        USA    Ben's Shop         10
# 1056 Sanchez St     USA       Sanchez         12
# 551 Alvarado St     USA    Richvalley         20

# %%
df8["Continent"] = df8.shape[0]*["North America"]

# %%
df8
# Out:
#                  ID           City             State Country          Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA       Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA   Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA       Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees      Continent
# Address
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 332 Hill St             25  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
df8["Geo"] = df8["Country"] + ", " + "North America"
df8
# Out:
#                  ID           City             State Country          Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA       Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA   Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA       Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees      Continent                 Geo
# Address
# 3666 21st St             8  North America  USA, North America
# 735 Dolores St          15  North America  USA, North America
# 332 Hill St             25  North America  USA, North America
# 3995 23rd St            10  North America  USA, North America
# 1056 Sanchez St         12  North America  USA, North America
# ...

# %%
df8_t = df8.T
df8_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# ID                          1                   2                   3
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent       North America       North America       North America
# Geo        USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# ID                          4                   5                   6
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# ...

# %%
#create new column.. df7_t["My Address"] = ["My City", "My Country", 10 , 7, "My Shop", "My State"]

# %%
#geocoding address to lat/long
#splicing dataframes
df9 = pandas.read_csv("./sample_data/supermarkets-semi-colons.txt", sep=";")
df9 = df9.set_index("ID")
df9
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#import geopy
#dir(geopy)
from geopy.geocoders import Nominatim

# %%
nom=Nominatim(scheme="http")

# %%
loc = nom.geocode("3995 23rd St, San Francisco, CA 94114")
loc
#print(loc)
#type(loc)
#dir(geopy.location.Location)
# Out:
# Location(3995, 23rd Street, Noe Valley, SF, California, 94114, United States of America, (37.7529648, -122.4317141, 0.0))

# %%
import pandas
df = pandas.read_csv("./sample_data/supermarkets.csv")
df.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#create fully formatted address
df["FullAddress"] = df["Address"]+ ", " + df["City"] + ", " + df["State"] + ", " + df["Country"]
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                        FullAddress
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
#pandas does not need to iterate. 
df["Coordinates"] = df["FullAddress"].apply(nom.geocode)
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                        FullAddress  \
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df.Coordinates[0].latitude
# Out:
# 37.7554451

# %%
#get lat / long
df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude if x != None else None) #use lambda,if not none,
df["Longitude"] = df["Coordinates"].apply(lambda x: x.longitude if x != None else None) #use lambda,if not none,
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                        FullAddress  \
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df_new = df[["ID", "Address","City","State","Country","Latitude", "Longitude"]]
df_new
# Out:
#    ID          Address           City             State Country   Latitude  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA  37.755445
# 1   2   735 Dolores St  San Francisco          CA 94119     USA        NaN
# 2   3      332 Hill St  San Francisco  California 94114     USA  37.756102
# 3   4     3995 23rd St  San Francisco          CA 94114     USA  37.752965
# 4   5  1056 Sanchez St  San Francisco        California     USA  37.748362
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA  37.753666
#
#     Longitude
# 0 -122.438770
# 1         NaN
# 2 -122.421041
# 3 -122.431714
# 4 -122.429346
# 5 -122.434440

# %%
#full script:
from geopy.geocoders import Nominatim
nom=Nominatim(scheme="http")
import pandas
dfl = pandas.read_csv("./sample_data/supermarkets.csv")
dfl.set_index("ID")
#create fully formatted address
dfl["FullAddress"] = dfl["Address"]+ ", " + dfl["City"] + ", " + dfl["State"] + ", " + dfl["Country"]
dfl["Coordinates"] = dfl["FullAddress"].apply(nom.geocode)
#get lat / long
dfl["Latitude"] = dfl["Coordinates"].apply(lambda x: x.latitude if x != None else None) #use lambda,if not none,
dfl["Longitude"] = dfl["Coordinates"].apply(lambda x: x.longitude if x != None else None) #use lambda,if not none,
#select final results to display
df_ll = dfl[["ID", "Address","City","State","Country","Latitude", "Longitude"]]
df_ll
# Out:
#    ID          Address           City             State Country   Latitude  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA  37.755445
# 1   2   735 Dolores St  San Francisco          CA 94119     USA        NaN
# 2   3      332 Hill St  San Francisco  California 94114     USA  37.756102
# 3   4     3995 23rd St  San Francisco          CA 94114     USA  37.752965
# 4   5  1056 Sanchez St  San Francisco        California     USA  37.748362
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA  37.753666
#
#     Longitude
# 0 -122.438770
# 1         NaN
# 2 -122.421041
# 3 -122.431714
# 4 -122.429346
# 5 -122.434440
